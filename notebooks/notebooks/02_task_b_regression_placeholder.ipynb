# %% [markdown]
# # Task B — Regression Placeholder
#
# This notebook is a placeholder for the regression portion of the DS230 final project.
#
# Recommended target: `log_shares = np.log1p(shares)`.

# %% [markdown]
# ## Planned workflow
#
# 1. Reuse the same data cleaning and feature engineering functions from `src/`.
# 2. Split data before preprocessing.
# 3. Train regression models such as Linear Regression, Ridge, Lasso, Random Forest Regressor, XGBoost Regressor.
# 4. Evaluate using MAE, MSE, RMSE, R², adjusted R², residual plots, Q-Q plot, and heteroscedasticity tests.
# 5. Compare with the classification findings and recommend a final regression model.

# %%
# TODO: Implement Task B regression workflow here.
